# %% [markdown]
# ###Linear Classifier로 XOR Gate를 구현하는게 실습입니다.
# 원래라면 학습 과정을 통해 구현해야하지만 배운게 없으니 직관적으로 만들어 볼 것입니다.
#
# XOR게이트는 하나의 게이트가 아닌 여러개의 게이트로 구성해야합니다.
#
# 그래서 저희는 각각 AND,OR,NAND를 만들고 이를 이용해 XOR 게이트를 만들겠습니다.

# %%
import numpy as np

# %% [markdown]
# 첫번째 AND 게이트입니다. AND게이트는 두값이 모두 1일때만 1을 반환합니다

# %%
def AND(x1, x2):
    x = ??
    w = ?? #AND 게이트의 가중치입니다.
    b = ?? #AND게이트의 bias입니다.
    tmp = ?? #세션때 다룬 linear classifier를 코드로 구현해야합니다.


    if tmp <= 0: 
        return 0
    else:
        return 1

# %% [markdown]
# 두 번째 NAND 게이트입니다. NAND는 AND 게이트의 반대로 두 값이 모두 1일때만 0을 반환합니다.

# %%
def NAND(x1, x2):
    x = ??
    w = ?? 
    b = ?? 
    tmp = ??  #linear classifier
    if tmp <= 0:
        return 0
    else:
        return 1

# %% [markdown]
# 세번째 OR게이트입니다. OR 게이트는 값 중 하나라도 1이 있다면 1을 반환합니다.

# %%
def OR(x1, x2):
    x = ??
    w = ??
    b = ??
    tmp = ??
    if tmp <= 0:
        return 0
    else:
        return 1

# %% [markdown]
# 위의 3가지 게이트를 활용하여서 XOR 게이트를 완성하시면 됩니다.

# %%
def XOR(x1, x2):
    ??
    return y

# %%
print(XOR(1,0),XOR(0,1),XOR(1,1),XOR(0,0))
# Out:
# 1 1 0 0
